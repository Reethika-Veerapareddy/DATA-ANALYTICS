# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhila06-123/Data-Analytics/blob/main/prescriptive_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Dataset
patient_name = ["Akhi","anu","smiley","kiyansh","asri"]

Age = [20,65,45,85,70]

condition = ["serious","normal","critical","serious","normal"]

oxygen_level = [95, 98, 82, 88, 97]

bed_availability = 3

# Create DataFrame
df = pd.DataFrame({
    "Patient_Name": patient_name,
    "Age": Age,
    "Condition": condition,
    "Oxygen_Level": oxygen_level,
    "Bed_Availability": bed_availability
})

print("Patient Dataset")
print(df)

print("\nPrescriptive Analysis with Priority\n")

priority_list = []

for i in range(len(df)):

    priority = 0

    print("Patient:", df["Patient_Name"][i])

    # Oxygen level condition + priority
    if df["Oxygen_Level"][i] < 85:
        print("Recommendation: Immediate oxygen support required")
        priority += 3

    elif df["Oxygen_Level"][i] < 90:
        print("Recommendation: Low oxygen level - monitor closely")
        priority += 2

    else:
        print("Recommendation: Oxygen level is stable")
        priority += 1

    # Condition-based priority
    if df["Condition"][i] == "critical":
        print("Action: Shift patient to ICU immediately")
        priority += 3

    elif df["Condition"][i] == "serious":
        print("Action: Continuous monitoring required")
        priority += 2

    else:
        print("Action: Regular observation")
        priority += 1

    allocation = []
beds_left = bed_availability

for i in range(len(df_sorted)):
    if beds_left > 0:
        allocation.append("Admitted (Bed Assigned)")
        beds_left -= 1
    else:
        allocation.append("Waiting (No Bed Available)")

df_sorted["Bed_Status"] = allocation

print("\nFinal Bed Allocation Based on Priority:\n")
print(df_sorted)
# Out:
# Patient Dataset
#   Patient_Name  Age Condition  Oxygen_Level  Bed_Availability
# 0         Akhi   20   serious            95                 3
# 1          anu   65    normal            98                 3
# 2       smiley   45  critical            82                 3
# 3      kiyansh   85   serious            88                 3
# 4         asri   70    normal            97                 3
#
# Prescriptive Analysis with Priority
#
# Patient: Akhi
# Recommendation: Oxygen level is stable
# Action: Continuous monitoring required
# Patient: anu
# Recommendation: Oxygen level is stable
# Action: Regular observation
# Patient: smiley
# Recommendation: Immediate oxygen support required
# Action: Shift patient to ICU immediately
# Patient: kiyansh
# Recommendation: Low oxygen level - monitor closely
# Action: Continuous monitoring required
# Patient: asri
# Recommendation: Oxygen level is stable
# Action: Regular observation
#
# Final Bed Allocation Based on Priority:
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the occurrences of each bed status
bed_status_counts = df_sorted['Bed_Status'].value_counts().reset_index()
bed_status_counts.columns = ['Bed_Status', 'Count']

# Create the bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x='Bed_Status', y='Count', data=bed_status_counts, palette='viridis', hue='Bed_Status', legend=False)
plt.title('Bed Allocation Status')
plt.xlabel('Bed Status')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
